# %%
import pandas as pd

# %%
BASE = r"C:\Users\FL4K\OneDrive - PETROBRAS\Documentos\1. ESTRUTURACAO DADOS\automacao-encerramento-comercial-om\dados\input\ordens_para_encerrar.xlsx"
df = pd.read_excel(BASE, skiprows=1)
df = df.dropna(how='all')
df = df.dropna(axis=1, how='all')
df = df.reset_index(drop=True)
df.columns = df.columns.str.strip()
df['Ordem'] = df['Ordem'].astype(int)
df
# Out:
#           Ordem
# 0    2031234509
# 1    2031015073
# 2    2030495209
# 3    2031015080
# 4    2031015082
# ..          ...
# 897  2031146733
# 898  2031146623
# 899  2031146622
# 900  2031146726
# 901  2031146621
#
# [902 rows x 1 columns]
